# %% [markdown]
# # 04 — Near-duplicate review (perceptual hash)
#
# Stage 2 already collapsed **metadata series** (same shelfmark + date). This pass
# looks for **photographic twins** among gallery rectos, especially the 1218 with
# no `signatuur`.
#
# 256-bit difference hash on `pages-recto/`. Known series pairs sit at Hamming
# 49–143 (re-frames, not pixel copies). New candidates use a tight cut
# (Hamming ≤ 32).
#
# Open `outputs/neardup_review.html`. Click a cluster (or Space) to mark **same
# leaf** — keep lowest `volgnummer`, drop the rest. Unmarked = keep all. Export
# `neardup_decisions.csv`. Nothing is removed from the gallery until an apply
# step.

# %%
from pathlib import Path
import runpy

runpy.run_path(str(Path("04_near_duplicates.py").resolve()))
