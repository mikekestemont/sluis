# %% [markdown]
# # 05 — Text zones (Kraken BLLA, largest region)
#
# Same detector as the legacy `01-preprocessing.ipynb` layout step, with three
# changes:
#
# 1. **Largest region only** (bbox area). Extra BLLA regions are recorded but not
#    cropped.
# 2. **No binarize** — Sauvola is Stage 5.
# 3. **Coordinates kept** in `data/zones.json` on the baked recto *and* mapped
#    back to `archive-original/` stored pixels (inverse EXIF) so published
#    originals can show the same box.
#
# Crops: `images/pages-zoned/`. Review: `outputs/zone_review.html`.
# Resume-safe (`data/zones_blla.jsonl`).

# %%
# Kernel: Python (sluis). Full run (hours). Resume if interrupted.
# ! python 05_blla_zones.py --device mps --qc-every 0

# Rebuild the review sheet from whatever is already segmented:
! python 05_blla_zones.py --qc-only
